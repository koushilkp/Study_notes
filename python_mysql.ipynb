# %%
pip install PYMYSQL
# Out:
# ...
#
# ...
#      ---------------------------------------- 43.8/43.8 kB 2.2 MB/s eta 0:00:00
# ...

# %%
import pymysql

# %%
import sqlalchemy as sa

# %%
pip install SQLAlchemy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import os

# %%
dh1=dir(pd)
dh1
# dh2=dh1.count()
dh2=pd.DataFrame(dh1)
dh2.shape[0]
# Out:
# 141

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [38], in <cell line: 1>()
# ----> 1 lst_dir(pd)
#
# NameError: name 'lst_dir' is not defined

# %%
import pandas as pd

# %%
engine=sa.create_engine('mysql+pymysql://root:root@localhost:3306/db_test')
engine
# Out:
# Engine(mysql+pymysql://root:***@localhost:3306/db_test)

# %%
engine1=sa.create_engine('mysql+pymysql://root:root@localhost:3306/koushil_db')
engine1
# Out:
# Engine(mysql+pymysql://root:***@localhost:3306/koushil_db)

# %% [markdown]
# ### read table

# %%
df=pd.read_sql_table('emp_data',engine1)
df
# Out:
#       EmpID     FName     LName Gender                         EMail  Salary  \
# 0    677509      Lois    Walker      F       lois.walker@hotmail.com  168251
# 1    940761    Brenda  Robinson      F     brenda.robinson@gmail.com   51063
# 2    428945       Joe  Robinson      M        joe.robinson@gmail.com   50155
# 3    408351     Diane     Evans      F         diane.evans@yahoo.com  180294
# 4    193819  Benjamin   Russell      M  benjamin.russell@charter.net  117642
# ..      ...       ...       ...    ...                           ...     ...
# 204  639892      Jose      Hill      M         jose.hill@hotmail.com  129774
# 205  704709    Harold    Nelson      M       harold.nelson@gmail.com  156194
# 206  461593    Nicole      Ward      F         nicole.ward@yahoo.com   95673
# 207  392491   Theresa    Murphy      F      theresa.murphy@gmail.com   51015
# 208  495141     Tammy     Young      F       tammy.young@comcast.net   93650
#
#           LOC  MGR_ID  DEPT_ID
# ...

# %%
df=pd.read_sql_table('emp_data',engine)
df
# Out:
#      EmpID     FName     LName Gender                         EMail  Salary  \
# 0   677509      Lois    Walker      F       lois.walker@hotmail.com  168251
# 1   940761    Brenda  Robinson      F     brenda.robinson@gmail.com   51063
# 2   428945       Joe  Robinson      M        joe.robinson@gmail.com   50155
# 3   408351     Diane     Evans      F         diane.evans@yahoo.com  180294
# 4   193819  Benjamin   Russell      M  benjamin.russell@charter.net  117642
# ..     ...       ...       ...    ...                           ...     ...
# 95  639892      Jose      Hill      M         jose.hill@hotmail.com  129774
# 96  704709    Harold    Nelson      M       harold.nelson@gmail.com  156194
# 97  461593    Nicole      Ward      F         nicole.ward@yahoo.com   95673
# 98  392491   Theresa    Murphy      F      theresa.murphy@gmail.com   51015
# 99  495141     Tammy     Young      F       tammy.young@comcast.net   93650
#
#          LOC  MGR_ID  DEPT_ID
# ...

# %% [markdown]
# ### read query

# %%
df=pd.read_sql_query('select * from emp_data order by empid limit 5',engine)
df1=df.iloc[0:3]
df1.describe()
# Out:
#                EmpID         Salary         MGR_ID  DEPT_ID
# count       3.000000       3.000000       3.000000      3.0
# mean   149165.333333  124281.333333  477655.000000     20.0
# std     12623.726721   38838.064606      41.904654     10.0
# min    134841.000000   82965.000000  477619.000000     10.0
# 25%    144415.000000  106400.500000  477632.000000     15.0
# 50%    153989.000000  129836.000000  477645.000000     20.0
# 75%    156327.500000  144939.500000  477673.000000     25.0
# max    158666.000000  160043.000000  477701.000000     30.0

# %% [markdown]
# ### read sql

# %%
df=pd.read_sql('emp_data',engine)
df
# Out:
#      EmpID     FName     LName Gender                         EMail  Salary  \
# 0   677509      Lois    Walker      F       lois.walker@hotmail.com  168251
# 1   940761    Brenda  Robinson      F     brenda.robinson@gmail.com   51063
# 2   428945       Joe  Robinson      M        joe.robinson@gmail.com   50155
# 3   408351     Diane     Evans      F         diane.evans@yahoo.com  180294
# 4   193819  Benjamin   Russell      M  benjamin.russell@charter.net  117642
# ..     ...       ...       ...    ...                           ...     ...
# 95  639892      Jose      Hill      M         jose.hill@hotmail.com  129774
# 96  704709    Harold    Nelson      M       harold.nelson@gmail.com  156194
# 97  461593    Nicole      Ward      F         nicole.ward@yahoo.com   95673
# 98  392491   Theresa    Murphy      F      theresa.murphy@gmail.com   51015
# 99  495141     Tammy     Young      F       tammy.young@comcast.net   93650
#
#          LOC  MGR_ID  DEPT_ID
# ...

# %%
df=pd.read_sql('emp_data',engine)
df
# Out:
#      EmpID     FName     LName Gender                         EMail  Salary  \
# 0   677509      Lois    Walker      F       lois.walker@hotmail.com  168251
# 1   940761    Brenda  Robinson      F     brenda.robinson@gmail.com   51063
# 2   428945       Joe  Robinson      M        joe.robinson@gmail.com   50155
# 3   408351     Diane     Evans      F         diane.evans@yahoo.com  180294
# 4   193819  Benjamin   Russell      M  benjamin.russell@charter.net  117642
# ..     ...       ...       ...    ...                           ...     ...
# 95  639892      Jose      Hill      M         jose.hill@hotmail.com  129774
# 96  704709    Harold    Nelson      M       harold.nelson@gmail.com  156194
# 97  461593    Nicole      Ward      F         nicole.ward@yahoo.com   95673
# 98  392491   Theresa    Murphy      F      theresa.murphy@gmail.com   51015
# 99  495141     Tammy     Young      F       tammy.young@comcast.net   93650
#
#          LOC  MGR_ID  DEPT_ID
# ...

# %%
df=pd.read_sql('select * from emp_data limit 10',engine)
df
# Out:
#     EmpID     FName     LName Gender                         EMail  Salary  \
# 0  677509      Lois    Walker      F       lois.walker@hotmail.com  168251
# 1  940761    Brenda  Robinson      F     brenda.robinson@gmail.com   51063
# 2  428945       Joe  Robinson      M        joe.robinson@gmail.com   50155
# 3  408351     Diane     Evans      F         diane.evans@yahoo.com  180294
# 4  193819  Benjamin   Russell      M  benjamin.russell@charter.net  117642
# 5  499687   Patrick    Bailey      M        patrick.bailey@aol.com   72305
# 6  539712     Nancy     Baker      F            nancy.baker@bp.com   98189
# 7  380086     Carol    Murphy      F        carol.murphy@gmail.com   60918
# 8  477616   Frances     Young      F       frances.young@gmail.com  121587
# 9  162402     Diana  Peterson      F  diana.peterson@hotmail.co.uk   43010
#
#         LOC  MGR_ID  DEPT_ID
# 0    DALLAS  677509       10
# 1   CHICAGO  940761       10
# 2   CHICAGO  428945       10
# ...

# %% [markdown]
# ### convert dataframe into db table

# %%
df.to_sql(name='emp_data',con=engine,index=False)
df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [68], in <cell line: 1>()
# ----> 1 df.to_sql(name='emp_data',con=engine,index=False)
#       2 df
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\generic.py:2951, in NDFrame.to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2794 """
#    2795 Write records stored in a DataFrame to a SQL database.
#    2796
#    (...)
#    2947 [(1,), (None,), (2,)]
#    2948 """  # noqa:E501
#    2949 from pandas.io import sql
# -> 2951 return sql.to_sql(
#    2952     self,
#    2953     name,
#    2954     con,
#    2955     schema=schema,
#    2956     if_exists=if_exists,
#    2957     index=index,
#    2958     index_label=index_label,
#    2959     chunksize=chunksize,
#    2960     dtype=dtype,
#    2961     method=method,
#    2962 )
#
# ...

# %%
df.to_sql(name='emp_data',con=engine,index=False,if_exists='replace')    #very very imp for connect and replace/append
# Out:
# 10

# %%
df.to_sql(name='emp_data',con=engine,index=False,if_exists='append')
# Out:
# 10
