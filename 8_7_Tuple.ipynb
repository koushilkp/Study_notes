# %% [raw]
# # Tuple
# 1.Immutable
# 2.Ordered
# 3.Allow duplicates
# 4.Comma Seperated
# 5.Enclosed by ()
# 6.Fixed length
# 7.less Functional  # index count
# 8.Tuple is faster than list # Tuple are immutable  # Tuple are immutable so, it does't
# 9.It require less memory
# 10.We can add multiple datatypes

# %%
tuple1 = ()
type(tuple1)
# Out:
# tuple

# %%
tuple1 = (1)
type(tuple1)
# Out:
# int

# %%
tuple1 = (1,)
type(tuple1)
# Out:
# tuple

# %%
tuple1 = (1,)
type(tuple1)
# Out:
# tuple

# %%
tuple1 = 1,2,3,4
type(tuple1)
# Out:
# tuple

# %%
tuple1 = ("Python")
type(tuple1)
# Out:
# str

# %%
tuple1 = ("Python",)
type(tuple1)
# Out:
# tuple

# %%
tuple1 = (1,2.3,"Python",[1,2,32,44])
tuple1
# Out:
# (1, 2.3, 'Python', [1, 2, 32, 44])

# %%
tuple1 = (1,2.3,"Python",[1,2,32,44])
type(tuple1)
# Out:
# tuple

# %%
tuple1 = ([1,2.3,"Python",[1,2,32,44]])# list
type(tuple1)
# Out:
# list

# %%
tuple1 = ([1,2.3,"Python",[1,2,32,44]],)# tuple
type(tuple1)
# Out:
# tuple

# %% [markdown]
# ## Access items from tuple

# %%
tuple1 = ([1,2.3,"Python",[1,2,32,44]],)# tuple
tuple1[0][2]
# Out:
# 'Python'

# %%
tuple1 = ([1,2.3,"Python",[1,2,32,44]],)# tuple
tuple1[0][3][3]
# Out:
# 44

# %%
tuple1 = ([1,2.3,"Python",[1,2,32,44]],)# tuple
tuple1[0][3][-1]
# Out:
# 44

# %%
tup1 = (100,200,300,400,500,600,700)  # 400,500,600
tup1[-4:-1]
tup1[3:6]
tup1[3:-1]
# Out:
# (400, 500, 600)

# %%
shubham salokhe20:47
[-4:-1]
VIPIN SAINI20:47
tup1[3]
vishwaj rathod20:47
3:-1
Physics with Jumed20:47
[3:7]
AMAR SHRINATH20:47
tup1[3:6]
Sudhir Pawar 520:47
3;-1
Aditi Shalu20:47
[-4][-1]
Lalit Patil20:47
tup1[3:-1]
satyam kalyane20:47
[3][5]
Sumit Deshmane20:47
[3][-1]
Chetan Tengse20:47
[3:6]

# %%
tup1 = (100,200,300,400,500,600,700)  # 500,400,300
tup1[4:1:-1]
# tup1[-3:-6:-1]
# tup1[4:1:-1]
# Out:
# (500, 400, 300)

# %%
Physics with Jumed20:50
[2:5:-1]
shubham salokhe20:50
[-3:2"-1]
Aditi Shalu20:50
[-3:-6:-1]
SHAUMIL SAHARIYA20:50
tup1[-3:2:-1]
siddhesh jadhav20:50
[-1;-4]
Pradeep Bagal20:50
tup1[3:6:-1]
Shweta Bhalerao20:50
[-3:-6]
VIPIN SAINI20:50
tup1[-4:-2:-1]
Prasad Sakharekar20:50
[-3:-6]
Priyanka Nangare20:50
tup[-3:3:-1]
Rajdip Borde20:50
[-3:-6:1]
DATTATRAY KOHAKADE20:50
[-3:-6:-1
ankit bhagat20:51
[-3:-6:-1]
Koushil KP20:50
[-3:2:-1]
Viplav Gotmare20:51
[-3:-6:-1]
SUJATA ANGULWAR20:51
[3:6:-1]
Tanmay Sonawane20:51
[-3:-2:-1]
Chetan Tengse20:51
[-3:-6]
Sameer Ghodake20:51
tup1[-2:-6:-1]
Sneha Thorat20:51
[-3:-6]
AMAR SHRINATH20:51
tup1[3:6:-1]
kedar Ghanwat20:51
tup1[-3:-6]
santosh kumar20:51
[-6][-3]
vishwaj rathod20:51
-3:-6:-1
swapnil more20:51
tup1[-3:3:-1]
Vivek Bakale20:51
[-3:-6:-1]
Santosh More20:51
tup1[3:-1:-1]
Bhagyashri Kotame20:51
tup1[[4:2]
siddhesh jadhav20:51
[-1:-4:-1]
Hitendra Katre20:51
tup[3:6:-1]
SHUBHAM AWARE PATIL20:51
tuple1[2:5:-1]
Sandip Lengare20:51
tup1[-3:-6:-1]
Virkant Kole20:51
[-3:-2:-1]
Diksha Channe20:51
[-3:-6:-1]
Tabish Qazi20:51
tuol1[-3:-5:-1]
sagar Sonawane20:51
[-3:-6:-1]
Aditi Shalu20:51
[5:2:-1]
Sonal Wakchaure20:51
[-3:-6:-1]
Vikram Chaure20:51
[-3:-6:-1]
Priyesh Tupkar20:51
[-6:-3:-1]
shailesh patil20:51
[-3:-6:-1]
Shweta Bhalerao20:51
[-3:-6:-1]
snehal kokate20:52
[4:1:-1]
SHILPA CHARAPALE20:52
tup1[-3:-6:-1]
Amol Hase20:52
-3-6-1
Suraj Jadhav20:52
tup1[-3:-6:-1]
SUJATA ANGULWAR20:52
[-3:-6:-1]
Mahesh Swami20:52
tup1[-3:-6:-1]
Gajanan Khade20:52
[::-3:6]
ankur soni20:52
[-3:-5:-1]
Mahesh Shinde20:52
[-3:-6:-1]
Sumit Deshmane20:52
tup1[-3:-6:-1]
Saurabh Birhade20:52
[2:-2][::-1]

# %% [markdown]
# ## Tuple to list

# %%
tup1 = (5,4,3,2)
print(f"Type of given variable is>>>>", type(tup1))
print("*"*100)
lst1 = list(tup1)
print(f"Type of given variable is>>>>", type(lst1))
lst1[1] ="Python"
print("*"*100)
new_tuple = tuple(lst1)
print(f"Type of given variable is>>>>", type(new_tuple),">>>>>",new_tuple)
# Out:
# Type of given variable is>>>> <class 'tuple'>
# ****************************************************************************************************
# Type of given variable is>>>> <class 'list'>
# ****************************************************************************************************
# Type of given variable is>>>> <class 'tuple'> >>>>> (5, 'Python', 3, 2)

# %%
tup1 = (5,4,3,2)
tup1[1] = "Python"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8964/2149378648.py in <module>
#       1 tup1 = (5,4,3,2)
# ----> 2 tup1[1] = "Python"
#
# TypeError: 'tuple' object does not support item assignment

# %%
tup1 =(2,3,4,5)
tup1.append("Python")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8964/2117454023.py in <module>
#       1 tup1 =(2,3,4,5)
# ----> 2 tup1.append("Python")
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
tup1 = (5,4,3,2)
print(f"Type of given variable is>>>>", type(tup1),">>>>>>",tup1)
print("*"*100)
lst1 = list(tup1)
print(f"Type of given variable is>>>>", type(lst1))
lst1.append("Python")
print("*"*100)
new_tuple = tuple(lst1)
print(f"Type of given variable is>>>>", type(new_tuple),">>>>>",new_tuple)
# Out:
# Type of given variable is>>>> <class 'tuple'> >>>>>> (5, 4, 3, 2)
# ****************************************************************************************************
# Type of given variable is>>>> <class 'list'>
# ****************************************************************************************************
# Type of given variable is>>>> <class 'tuple'> >>>>> (5, 4, 3, 2, 'Python')

# %%
str1 = "Python Data"
print(str1)
t1 = tuple(str1)
"_".join(t1)
# Out:
# Python Data
# 'P_y_t_h_o_n_ _D_a_t_a'

# %% [markdown]
# ## Delete

# %%
tup1 = (2,3,4,5)
tup1.remove(2)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8964/406181690.py in <module>
#       1 tup1 = (2,3,4,5)
# ----> 2 tup1.remove(2)
#
# AttributeError: 'tuple' object has no attribute 'remove'

# %%
tup1 = (2,3,4,5)
del tup1

# %%
tup1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8964/3559505791.py in <module>
# ----> 1 tup1
#
# NameError: name 'tup1' is not defined

# %%
tup1 = [2,3,4,5]
del tup1[1]

# %%
tup1
# Out:
# [2, 4, 5]

# %%
tup1 = (2,3,4,5)
del tup1[1]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8964/2171903599.py in <module>
#       1 tup1 = (2,3,4,5)
# ----> 2 del tup1[1]
#
# TypeError: 'tuple' object doesn't support item deletion

# %% [markdown]
# ## Two functions Index and count

# %%
tup1 =(2,3,4,5,6)
tup1.index(4)
# Out:
# 2

# %%
tup1 =(2,3,4,5,6)
tup1.index(6)
# Out:
# 4

# %%
tup1 =(2,3,4,5,6,1,2,3,1,4,1)
tup1.count(1)
# Out:
# 3

# %% [markdown]
# ## For loop

# %%
tup1 =(2,3,4,5,6,1,2,3,1,4,1)
for i in tup1:
    if i%2==0:print(i)
# Out:
# 2
# 4
# 6
# 2
# 4

# %%
tup1 =(2,3,4,5,6,1,2,3,1,4,1)
for index,value in enumerate(tup1):
    print("Index is>>>>>",index,"Item is>>>>>",value)
# Out:
# Index is>>>>> 0 Item is>>>>> 2
# Index is>>>>> 1 Item is>>>>> 3
# Index is>>>>> 2 Item is>>>>> 4
# Index is>>>>> 3 Item is>>>>> 5
# Index is>>>>> 4 Item is>>>>> 6
# Index is>>>>> 5 Item is>>>>> 1
# Index is>>>>> 6 Item is>>>>> 2
# Index is>>>>> 7 Item is>>>>> 3
# Index is>>>>> 8 Item is>>>>> 1
# Index is>>>>> 9 Item is>>>>> 4
# Index is>>>>> 10 Item is>>>>> 1

# %% [markdown]
# ## Use of list comprehension in tuple

# %%
sub_names = ("Hindi","Eng","Phy","Math")
print("Subject names are >>>",sub_names)
tup1 = [i.lower() for i in sub_namestu]
tup1
# Out:
# Subject names are >>> ('Hindi', 'Eng', 'Phy', 'Math')
# ['hindi', 'eng', 'phy', 'math']

# %%
sub_names = ("Hindi","Eng","Phy","Math")
print("Subject names are >>>",sub_names)
tup1 =tuple([i.lower() for i in sub_names])
"tup1
# Out:
# Subject names are >>> ('Hindi', 'Eng', 'Phy', 'Math')
# ('hindi', 'eng', 'phy', 'math')

# %% [markdown]
# ## Copy()

# %%
tup1 = (2,3,4,5)
tup2 = tup1
print(tup1)
print(tup2)
# Out:
# (2, 3, 4, 5)
# (2, 3, 4, 5)

# %%
tup1 = (2,3,4,5)
tup2 = tup1
tup1[0] = "Python"
print(tup1)
print(tup2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8964/3966807601.py in <module>
#       1 tup1 = (2,3,4,5)
#       2 tup2 = tup1
# ----> 3 tup1[0] = "Python"
#       4 print(tup1)
#       5 print(tup2)
#
# TypeError: 'tuple' object does not support item assignment

# %%
tup1 = (20,[10,50],45)
tup2 = tup1
tup1[1][0] = "Python"
print(tup1)
print(tup2)
# Out:
# (20, ['Python', 50], 45)
# (20, ['Python', 50], 45)

# %%
tup1 = (20,[10,50],45)
tup2 = tup1.copy()
tup1[1][0] = "Python"
print(tup1)
print(tup2)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8964/3021071794.py in <module>
#       1 tup1 = (20,[10,50],45)
# ----> 2 tup2 = tup1.copy()
#       3 tup1[1][0] = "Python"
#       4 print(tup1)
#       5 print(tup2)
#
# AttributeError: 'tuple' object has no attribute 'copy'

# %% [markdown]
# ## Deepcopy()

# %%
import copy
tup1 = (20,[10,50],45)
tup2 = copy.deepcopy(tup1)
tup1[0] = "Python"
# print(tup1)
# print(tup2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8964/791034818.py in <module>
#       2 tup1 = (20,[10,50],45)
#       3 tup2 = copy.deepcopy(tup1)
# ----> 4 tup1[0] = "Python"
#       5 # print(tup1)
#       6 # print(tup2)
#
# TypeError: 'tuple' object does not support item assignment

# %%
import copy
tup1 = (20,[10,50],45)
tup2 = copy.deepcopy(tup1)
tup1[1][0]  = "Python"
print(tup1)
print(tup2)
# Out:
# (20, ['Python', 50], 45)
# (20, [10, 50], 45)

# %%
tup1 = (20,[10,50],45)
tup2 = copy.deepcopy(tup1)
tup1[1][0] = "Python"
print(tup1)
print(tup2)
# Out:
# (20, ['Python', 50], 45)
# (20, [10, 50], 45)

# %% [markdown]
# ### Plus Operator

# %%
tup1 = (1,2,3,4)
tup2 = (3,4,5,6)
tup3 = tup1 + tup2
tup3
# Out:
# (1, 2, 3, 4, 3, 4, 5, 6)

# %% [markdown]
# ## Sort()

# %%
tup1 = (1,2,3,4)
tup1.sort()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8964/2109689628.py in <module>
#       1 tup1 = (1,2,3,4)
# ----> 2 tup1.sort()
#
# AttributeError: 'tuple' object has no attribute 'sort'

# %%
tup1 = (100,2,30,4,1)
print(tup1)
print()
tup2 = tuple(sorted(tup1)) # Ascending
print(tup2)
# Out:
# (100, 2, 30, 4, 1)
#
# (1, 2, 4, 30, 100)

# %%
tup1 = (100,2,30,4,1)
print(tup1)
print()
tup2 = tuple(sorted(tup1,reverse=True)) # Descending
print(tup2)
# Out:
# (100, 2, 30, 4, 1)
#
# (100, 30, 4, 2, 1)

# %% [markdown]
# ## Reverse

# %%
tup1 = (100,2,30,4,1)
tup1.reverse()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8964/2892861456.py in <module>
#       1 tup1 = (100,2,30,4,1)
# ----> 2 tup1.reverse()
#
# AttributeError: 'tuple' object has no attribute 'reverse'

# %%
tup1 = (100,2,30,4,1)
print(tup1)
print()
tup2 = tuple(reversed(tup1)) 
print(tup2)
# Out:
# (100, 2, 30, 4, 1)
#
# (1, 4, 30, 2, 100)

# %%
lst = [1,2,3,4]
sum(lst)
# Out:
# 10

# %%
lst = [1,2,3,4]
sum1 = 0
for i in lst:
    sum1=sum1+i
print(sum1)
# Out:
# 10

# %%
for i in lst: #[1, 2, 3, 4]
    sum1 = 0 # wrong
    sum1 +=i  # 1
print(sum1)
# Out:
# 4

# %%
del sum1

# %%
for i in lst: #[1, 2, 3, 4]
#     sum1 = 0 # wrong
    sum1 +=i  # 1
print(sum1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8964/756452724.py in <module>
#       1 for i in lst: #[1, 2, 3, 4]
#       2 #     sum1 = 0 # wrong
# ----> 3     sum1 +=i  # 1
#       4 print(sum1)
#
# NameError: name 'sum1' is not defined

# %% [markdown]
# ## List comprehension

# %%
lst = [2,3,4,5,6,7]
lst1 = [i for i in lst if i%2 == 0]
lst1
# Out:
# [2, 4, 6]

# %%
lst = ["Pune","mumbai","DelHi","HYDRABAD"]  # "mu"
lst1 = [i for i in lst if i.islower() == True]
lst1
# Out:
# ['mumbai']

# %%
Mahesh Swami21:42
i for i in lst if i.islower()==True
Santosh More21:42
lst=[ i for i in lst1 if i.islower()==True]
Lalit Patil21:42
lst=[ i for i in lst1 if i.islower()==True]
Kamini Patil21:43
lst1=[i for i in lst1 if i.islower()==true]

# %%
lst = ["Pune","mumbai","DelHi","HYDRABAD"]  # "mu"
lst1 = [i.upper() for i in lst ]
lst1
# Out:
# ['PUNE', 'MUMBAI', 'DELHI', 'HYDRABAD']

# %% [markdown]
# ## Loops in Python

# %% [raw]
# 1.For loop
# 2.While loop

# %% [raw]
# syntax > for loop
# for var in sequence: # str,list,tuple,range,set,numpy,pandas data frame
#     statement1

# %%
Syntax > while loop
while condition :
    statement 1

# %%
while 5<10: # True
    print("We are in while loop")
# Out:
# We are in while loop
# We are in while loop
# We are in while loop
# We are in while loop
# We are in while loop
# We are in while loop
# We are in while loop
# We are in while loop
# We are in while loop
# We are in while loop
# We are in while loop
# We are in while loop
# We are in while loop
# We are in while loop
# We are in while loop
# We are in while loop
# We are in while loop
# We are in while loop
# We are in while loop
# We are in while loop
# We are in while loop
# We are in while loop
# We are in while loop
# We are in while loop
# We are in while loop
# We are in while loop
# We are in while loop
# We are in while loop
# We are in while loop
# We are in while loop
# We are in while loop
# We are in while loop
# We are in while loop
# We are in while loop
# We are in while loop
# We are in while loop
# We are in while loop
# We are in while loop
# We are in while loop
# We are in while loop
# We are in while loop
# We are in while loop
# We are in while loop
# ...

# %%
i = 0
while i <10:
    print("Data science")
    break
    print("we are using break")
# Out:
# Data science

# %%
i = 0
while i <10:
    print("Data science")
  
    print("we are using break")
    break
# Out:
# Data science
# we are using break

# %%
import os
import pandas as pd
path = os.getcwd()
file_list = os.listdir(path)
file_list
# Out:
# ['.ipynb_checkpoints', '8_7_Tuple.ipynb', 'Sales_data.csv']

# %%
import os
import pandas as pd
path = os.getcwd()
file_list = os.listdir(path)
for file in file_list:
    if file.endswith(".csv"):
        print(file)
# Out:
# Sales_data.csv

# %%
import os
import pandas as pd
path = os.getcwd()
file_list = os.listdir(path)
for file in file_list:
    if file.endswith(".csv"):
        df = pd.read_csv(file)
df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
df.tail()
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 8518         Snack Foods  214.5218            OUT013
# 8519        Baking Goods  108.1570            OUT045
# 8520  Health and Hygiene   85.1224            OUT035
# 8521         Snack Foods  103.1332            OUT018
# 8522         Soft Drinks   75.4670            OUT046
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 8518                       1987        High               Tier 3
# 8519                       2002         NaN               Tier 2
# ...

# %%
df.sample(5)
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 1299           FDO58        19.60          Low Fat         0.039577
# 5851           NCH55        16.35          Low Fat         0.034814
# 5482           NCQ17        10.30          Low Fat         0.000000
# 1038           FDU15        13.65          Regular         0.026643
# 6743           DRF51        15.75          Low Fat         0.166514
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 1299         Snack Foods  166.1526            OUT046
# 5851           Household  128.4020            OUT018
# 5482  Health and Hygiene  154.6630            OUT013
# 1038                Meat   37.9532            OUT049
# 6743               Dairy   38.0506            OUT018
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 1299                       1997       Small               Tier 1
# 5851                       2009      Medium               Tier 3
# ...

# %%
for i in df["Item_Fat_Content"]:
    print(i.upper())
# Out:
# LOW FAT
# REGULAR
# LOW FAT
# REGULAR
# LOW FAT
# REGULAR
# REGULAR
# LOW FAT
# REGULAR
# REGULAR
# LOW FAT
# REGULAR
# REGULAR
# REGULAR
# LOW FAT
# REGULAR
# LOW FAT
# REGULAR
# LOW FAT
# LOW FAT
# REGULAR
# REGULAR
# LOW FAT
# LOW FAT
# REGULAR
# LOW FAT
# REGULAR
# LOW FAT
# REGULAR
# REGULAR
# LOW FAT
# LOW FAT
# LOW FAT
# LOW FAT
# LOW FAT
# LOW FAT
# REGULAR
# REGULAR
# REGULAR
# LOW FAT
# LOW FAT
# LOW FAT
# LOW FAT
# LOW FAT
# REGULAR
# LF
# LOW FAT
# LOW FAT
# REGULAR
# REGULAR
# LOW FAT
# LOW FAT
# REGULAR
# LOW FAT
# LOW FAT
# LOW FAT
# LOW FAT
# LOW FAT
# LOW FAT
# LOW FAT
# LOW FAT
# REGULAR
# LOW FAT
# REGULAR
# LOW FAT
# LF
# LOW FAT
# REGULAR
# LOW FAT
# LOW FAT
# REGULAR
# REGULAR
# LOW FAT
# LOW FAT
# LOW FAT
# REGULAR
# LOW FAT
# LOW FAT
# LOW FAT
# LOW FAT
# LOW FAT
# REG
# LOW FAT
# LOW FAT
# REGULAR
# REGULAR
# LOW FAT
# REGULAR
# REGULAR
# LOW FAT
# LOW FAT
# LOW FAT
# LOW FAT
# LOW FAT
# LOW FAT
# LOW FAT
# LOW FAT
# REGULAR
# LOW FAT
# REGULAR
# LOW FAT
# ...
