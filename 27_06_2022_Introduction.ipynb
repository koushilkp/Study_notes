# %%
> new cell above the current cell - esc + a
> new cell below the current cell - esc + b
> To run current cell - ctrl +Enter
> To execute current cell and want to go next cell - shift + Enter
> To execute current cell and create blank cell - Alt+Enter
> to delete current cell > esc + dd

# %%
a = 5
b = 14
a + bd
# Out:
# 19

# %%
a = 5
b = 10
a + b
# Out:
# 15

# %% [markdown]
# # Introduction

# %%
Headline (main)> esc + 1 then shift +enter
Headline (sub)> esc + 2 then shift +enter

# %% [markdown]
# # Data Science

# %% [markdown]
# ## 1) Data Types

# %% [raw]
# Machine learning is a branch of artificial intelligence (AI) and computer science which focuses on the use of data and algorithms to imitate the way that humans learn, gradually improving its accuracy. IBM has a rich history with machine learning
# > esc + r
# > esc + y - want to go into code

# %%
# Image

# %%
esc + m

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![0_QYxNNYh6W9jO1b_-.png](attachment:0_QYxNNYh6W9jO1b_-.png)

# %% [raw]
# > esc + m then paste copy image then shift + Enter

# %% [markdown]
# # Comment

# %%
# single comment  ctrl + /
a = "DATA SCIENCE" # ajggadfg
print(a)
b ="Machine Learning"
print(b) # Data science
# Out:
# Machine Learning

# %%
def fun():
    """
    Machine learning is a field of inquiry devoted to understanding and 
    building methods that 'learn', that is, 
    methods that leverage data to improve performance on some set of tasks
    
    """
fun()

# %%
a = """Machine learning is a field of inquiry devoted to understanding and 
    building methods that 'learn', that is, 
    methods that leverage data to improve performance on some set of tasks"""
a
# Out:
# "Machine learning is a field of inquiry devoted to understanding and \n    building methods that 'learn', that is, \n    methods that leverage data to improve performance on some set of tasks"

# %%
''''''
